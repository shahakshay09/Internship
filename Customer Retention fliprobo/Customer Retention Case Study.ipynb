# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel("customer_retention_dataset.xlsx")

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#cheking shape
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # NO null values present in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# # All the columns are of object type other than '4 What is the Pin Code of where you shop online from? which is an int type.

# %%
df.describe(exclude='int')
# Out:
#        1Gender of respondent 2 How old are you?   \
# count                    269                 269
# unique                     2                   5
# top                   Female         31-40 years
# freq                     181                  81
# mean                     NaN                 NaN
# std                      NaN                 NaN
# min                      NaN                 NaN
# 25%                      NaN                 NaN
# 50%                      NaN                 NaN
# 75%                      NaN                 NaN
# max                      NaN                 NaN
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.describe(),linewidths=0.1,fmt='0.1f',annot=True)
plt.show()

# %%
df['1Gender of respondent'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['1Gender of respondent'])
plt.show()

# %% [markdown]
# # Female    181                    /                     Male       88

# %%
df['2 How old are you? '].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['2 How old are you? '])
plt.show()

# %%
df['3 Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(df['3 Which city do you shop online from?'])
plt.show()

# %%
df['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %%
df['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
plt.figure(figsize=(35,15))
sns.countplot(df['4 What is the Pin Code of where you shop online from?'])
plt.show()

# %%
df['5 Since How Long You are Shopping Online ?'].unique()
# Out:
# array(['Above 4 years', '3-4 years', '2-3 years', 'Less than 1 year',
#        '1-2 years'], dtype=object)

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['5 Since How Long You are Shopping Online ?'])
plt.show()

# %% [markdown]
# ### Above 4 years       98
#
#
#
# ### 2-3 years           65
#
#
#
# ### 3-4 years           47
#
#
#
# ### Less than 1 year    43
#
#
#
# ### 1-2 years           16
#
#
#
# The data shows that Most of the customers are using online shopping for more than 4 years. This indicates that there is a large number of repeat customers.
# There is also an increased number of customers using online shopping within 1 year than customers using online shopping for 1-2 years. This indicates that online shopping is getting popular again recently although there was a slight decrease in the 1-2 years' population.

# %%
df['7 How do you access the internet while shopping on-line?'].unique()
# Out:
# array(['Dial-up', 'Wi-Fi', 'Mobile Internet', 'Mobile internet'],
#       dtype=object)

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
plt.show()

# %% [markdown]
# ##### Mobile Internet and Mobile internet are same, lets combine it using lambda function

# %%
df['7 How do you access the internet while shopping on-line?'] = df['7 How do you access the internet while shopping on-line?'].apply(lambda x: 'Mobile internet' if x == 'Mobile interrnet' else x)

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
plt.show()

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    189
# Wi-Fi               76
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
df['8 Which device do you use to access the online shopping?'].unique()
# Out:
# array(['Desktop', 'Smartphone', 'Tablet', 'Laptop'], dtype=object)

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['8 Which device do you use to access the online shopping?'])
plt.show()

# %% [markdown]
# ##### Smartphone is the most used device to visit online shopping stores. About 52% of the customers use smartphone to visit the store.

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].unique()
# Out:
# array(['Window/windows Mobile', 'IOS/Mac', 'Android'], dtype=object)

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '])
plt.show()

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].unique()
# Out:
# array(['Search Engine', 'Content Marketing', 'Display Adverts'],
#       dtype=object)

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
plt.show()

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].unique()
# Out:
# array(['Search Engine', 'Via application', 'Direct URL', 'E-mail',
#        'Social Media'], dtype=object)

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
plt.show()

# %% [markdown]
# The repeat customers are using Search engines and applications to come back to the online stores after.
# Social media channel is the least used channel.

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ']
# Out:
# 0              6-10 mins
# 1      more than 15 mins
# 2             11-15 mins
# 3              6-10 mins
# 4      more than 15 mins
#              ...
# 264    more than 15 mins
# 265      Less than 1 min
# 266    more than 15 mins
# 267             1-5 mins
# 268           11-15 mins
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , Length: 269, dtype: object

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
plt.show()

# %% [markdown]
# From the dataset we can see that about 45.7% of the customers are taking atleast 15 mins to explore the store before making a purchase decision.
#
#
# At least 5.58% of the customers are on the store only for less than 1 mins before making a purchase. This could be because they know what they want and just visit to purchase it.

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].unique()
# Out:
# array(['E-wallets (Paytm, Freecharge etc.)', 'Credit/Debit cards',
#        'Cash on delivery (CoD)'], dtype=object)

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
plt.show()

# %% [markdown]
# For about 55% of the customers the preferred payment option is Credit/Debit cards.
#
#
# E-wallets are still the least preferred option.

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].unique()
# Out:
# array(['Sometimes', 'Very frequently', 'Never', 'Frequently'],
#       dtype=object)

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '])
plt.show()

# %% [markdown]
# A large portion of the population abandon the shopping cart sometimes.
#
#
# About 17.84% of the population never abandon the cart.
#
#
# About 17.5% of the customers abandon the cart frequently/very frequently.

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].unique()
# Out:
# array(['Lack of trust', 'Promo code not applicable',
#        'Better alternative offer', 'Change in price',
#        'No preferred mode of payment'], dtype=object)

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
plt.figure(figsize=(18,12))
sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
plt.show()

# %% [markdown]
# The top reason for abandoning the cart is that the customers have found a better alternative offers. This indicates that we need to keep the best offers up to date always.
#
#
#
# About 11.52% of the population have a lack of trust in the online stores. This can be fixed by updating the web security and letting the customers know how protected the store is through some policy pages.
#
#
#
# At least 5.2% of the customers did not see their preferred mode of payments.

# %%
df['18 The content on the website must be easy to read and understand'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'Strongly disagree (1)',
#        'Indifferent (3)'], dtype=object)

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.countplot(df['18 The content on the website must be easy to read and understand'])
plt.show()

# %% [markdown]
# bout 90% of the customers Strongly agree/agree that the content on the website must be easy to read and understand.

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].unique()
# Out:
# array(['Indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)'], dtype=object)

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.show()

# %% [markdown]
# About 77% of the population agree/Strongly agree that the information on similar products to the one highlighted is important for product comparison.

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].unique()
# Out:
# array(['Indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)', 'Strongly disagree (1)'], dtype=object)

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.show()

# %% [markdown]
# About 69% of the customers strongly agree/agree that the Complete information on listed seller and product being offered is important for purchase decision.

# %%
df['21 All relevant information on listed products must be stated clearly'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'Strongly disagree (1)',
#        'Dis-agree (2)'], dtype=object)

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0               Agree (4)
# 1      Strongly agree (5)
# 2               Agree (4)
# 3               Agree (4)
# 4               Agree (4)
#               ...
# 264             Agree (4)
# 265    Strongly agree (5)
# 266             Agree (4)
# 267             Agree (4)
# 268    Strongly agree (5)
# Name: 21 All relevant information on listed products must be stated clearly, Length: 269, dtype: object>

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['21 All relevant information on listed products must be stated clearly'])
plt.show()

# %% [markdown]
# About 90% of the customers feel that all relevant information on listed products must be stated clearly

# %%
df['22 Ease of navigation in website'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'Strongly disagree (1)',
#        'Dis-agree (2)'], dtype=object)

# %%
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['22 Ease of navigation in website'])
plt.show()

# %% [markdown]
# About 91% of the customers agree / strongly agree that ease of navigation is necessary in a website.

# %%
df['23 Loading and processing speed'].unique()
# Out:
# array(['Strongly disagree (1)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)', 'Indifferent (3)'], dtype=object)

# %%
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['23 Loading and processing speed'])
plt.show()

# %% [markdown]
# As expected most customers agree/strongly agree that loading and processing speed is important.

# %%
df['24 User friendly Interface of the website'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)',
#        'Strongly disagree (1)', 'Indifferent (3)'], dtype=object)

# %%
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'])
plt.show()

# %% [markdown]
# At least 70% of the customers strongly agree that the interface of the website should be user friendly.

# %%
df['25 Convenient Payment methods'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)'], dtype=object)

# %%
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df['25 Convenient Payment methods'])
plt.show()

# %% [markdown]
# 59% and 29.7% of the customers Strongly agree and agree respectively that the online store needs to have convenient payment methods.

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].unique()
# Out:
# array(['Disagree (2)', 'Strongly agree (5)', 'Agree (4)',
#        'indifferent  (3)'], dtype=object)

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
plt.show()

# %% [markdown]
# About 84% of the customers strongly agree/agree that the online retail store will fulfill its part of the transaction at the stipulated time.
#
#
#
# 4.46% of the population have doubts if they can trust that the online retail store will fulfill its part of the transaction at the stipulated time.
#
#
#
# At least 11.15% of the customers do not trust that the online retail store will fulfill its part of the transaction at the stipulated time.
#
#
#
# The indifferent and the disagreeing population gives us an idea about why about 28.25% of the people opt Cash on delivery payment option.

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['27 Empathy (readiness to assist with queries) towards the customers'])
plt.show()

# %% [markdown]
# It is good to see that 87% of the customers feel that the online shopping companies empathise towards their customers.

# %%
df['28 Being able to guarantee the privacy of the customer'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)'], dtype=object)

# %%
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['28 Being able to guarantee the privacy of the customer'])
plt.show()

# %% [markdown]
# Privacy is a very important aspect. It is good that none of the customers feel they have issues with privacy with the stores.

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)',
#        'Strongly disagree (1)'], dtype=object)

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.countplot(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])
plt.show()

# %%
df['30 Online shopping gives monetary benefit and discounts'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Strongly disagree (1)', 'Dis-agree (2)'], dtype=object)

# %%
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'])
plt.show()

# %%
df['32 Shopping online is convenient and flexible'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'indifferent (3)',
#        'Agree (4)'], dtype=object)

# %%
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['32 Shopping online is convenient and flexible'])
plt.show()

# %% [markdown]
# Most people believe Shopping online is convenient and flexible

# %%
df['31 Enjoyment is derived from shopping online'].unique()
# Out:
# array(['Strongly disagree (1)', 'Strongly agree (5)', 'indifferent (3)',
#        'Agree (4)', 'Dis-agree (2)'], dtype=object)

# %%
df['31 Enjoyment is derived from shopping online' ].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['31 Enjoyment is derived from shopping online'])
plt.show()

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)'], dtype=object)

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['33 Return and replacement policy of the e-tailer is important for purchase decision'])
plt.show()

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)',
#        'Dis-agree (2)', 'Strongly disagree (1)'], dtype=object)

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['34 Gaining access to loyalty programs is a benefit of shopping online'])
plt.show()

# %% [markdown]
# More people strongly agree that loyalty program are benefical for online shopping.

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)'], dtype=object)

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['35 Displaying quality Information on the website improves satisfaction of customers'])
plt.show()

# %% [markdown]
# Displaying quality Information on the website improves satisfaction of customers.

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].unique()
# Out:
# array(['Strongly agree (5)', 'Agree (4)', 'Dis-agree (2)'], dtype=object)

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['36 User derive satisfaction while shopping on a good quality website or application'])
plt.show()

# %% [markdown]
# Customers Strongly agree that customers derive satisfaction while shopping on a good quality website or application.

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)',
#        'Dis-agree (2)'], dtype=object)

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['37 Net Benefit derived from shopping online can lead to users satisfaction'])
plt.show()

# %% [markdown]
# Customers strongly agree that Net Benefit derived from online shopping  can lead to user satisfication.

# %%
df['38 User satisfaction cannot exist without trust'].unique()
# Out:
# array(['Strongly agree (5)', 'Agree (4)', 'Strongly disagree (1)',
#        'Dis-agree (2)', 'indifferent (3)'], dtype=object)

# %%
df['38 User satisfaction cannot exist without trust'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Strongly agree (5)
# 1      Strongly agree (5)
# 2               Agree (4)
# 3               Agree (4)
# 4      Strongly agree (5)
#               ...
# 264             Agree (4)
# 265    Strongly agree (5)
# 266             Agree (4)
# 267    Strongly agree (5)
# 268    Strongly agree (5)
# Name: 38 User satisfaction cannot exist without trust, Length: 269, dtype: object>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['38 User satisfaction cannot exist without trust'])
plt.show()

# %% [markdown]
#  Customers strongly agree/agree that user satisfaction cannot exist without trust.

# %%
df['39 Offering a wide variety of listed product in several category'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)'], dtype=object)

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['39 Offering a wide variety of listed product in several category'])
plt.show()

# %% [markdown]
# Customers strongly agree that offering a wide variety of listed product in several category is needed.

# %%
df['40 Provision of complete and relevant product information'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Disagree (2)'], dtype=object)

# %%
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['40 Provision of complete and relevant product information'])
plt.show()

# %%
df['41 Monetary savings'].unique()
# Out:
# array(['Disagree (2)', 'Strongly agree (5)', 'Agree (4)',
#        'indifferent (3)'], dtype=object)

# %%
df['41 Monetary savings'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            Disagree (2)
# 1      Strongly agree (5)
# 2      Strongly agree (5)
# 3      Strongly agree (5)
# 4      Strongly agree (5)
#               ...
# 264          Disagree (2)
# 265    Strongly agree (5)
# 266             Agree (4)
# 267             Agree (4)
# 268    Strongly agree (5)
# Name: 41 Monetary savings, Length: 269, dtype: object>

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['41 Monetary savings'])
plt.show()

# %% [markdown]
# Customers feel that there is Monetary savings in online shopping.

# %%
df['42 The Convenience of patronizing the online retailer'].unique()
# Out:
# array(['indifferent (3)', 'Agree (4)', 'Strongly agree (5)'], dtype=object)

# %%
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['42 The Convenience of patronizing the online retailer'])
plt.show()

# %%
df['43 Shopping on the website gives you the sense of adventure'].unique()
# Out:
# array(['Agree (4)', 'indifferent (3)', 'Strongly agree (5)',
#        'Dis-agree (2)', 'Strongly disagree (1)'], dtype=object)

# %%
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'])
plt.show()

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].unique()
# Out:
# array(['Agree (4)', 'indifferent (3)', 'Strongly agree (5)',
#        'Strongly disagree (1)', 'Dis-agree (2)'], dtype=object)

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'])
plt.show()

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].unique()
# Out:
# array(['Strongly agree (5)', 'indifferent (3)', 'Agree (4)',
#        'Strongly disagree (1)', 'Disagree (2)'], dtype=object)

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'])
plt.show()

# %% [markdown]
#  Customers strongly agree that there is some gratification in shopping on their favorite e-retailer.

# %%
df['46 Shopping on the website helps you fulfill certain roles'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)',
#        'Strongly disagree (1)', 'Dis-agree (2)'], dtype=object)

# %%
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'])
plt.show()

# %%
df['47 Getting value for money spent'].unique()
# Out:
# array(['Strongly agree (5)', 'Agree (4)', 'indifferent (3)'], dtype=object)

# %%
df['47 Getting value for money spent'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Strongly agree (5)
# 1      Strongly agree (5)
# 2               Agree (4)
# 3               Agree (4)
# 4      Strongly agree (5)
#               ...
# 264       indifferent (3)
# 265    Strongly agree (5)
# 266             Agree (4)
# 267       indifferent (3)
# 268    Strongly agree (5)
# Name: 47 Getting value for money spent, Length: 269, dtype: object>

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['47 Getting value for money spent'])
plt.show()

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].unique()
# Out:
# array(['Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com, Paytm.com'], dtype=object)

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
plt.figure(figsize=(20,12))
sns.set_style('darkgrid')
sns.countplot(df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '])
plt.show()

# %% [markdown]
# All of the combinations values have Amazon.in in them. This clearly shows that all the customers in this population have shopped from Amazon.in site.
#
#
# Flipkart.com site holds the 2nd place.
#
#
# About 30.48% of the customers have shopped from all 5 websites in the option(Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com).
#
#
# Amazon is the only site which has customers that have not shopped from other sites. There are about 5.95% of such customers.

# %%
df['Easy to use website or application'].unique()
# Out:
# array(['Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in', 'Amazon.in, Paytm.com', 'Flipkart.com'], dtype=object)

# %%
df['Easy to use website or application'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                              Paytm.com
# 1      Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                       Amazon.in, Paytm.com, Myntra.com
# 3      Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4      Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
#                              ...
# 264                                            Amazon.in
# 265                                         Flipkart.com
# 266                                            Amazon.in
# 267    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                            Amazon.in
# Name: Easy to use website or application, Length: 269, dtype: object>

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['Easy to use website or application'])
plt.show()

# %%
df['Visual appealing web-page layout'].unique()
# Out:
# array(['Flipkart.com', 'Amazon.in, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Flipkart.com, Myntra.com', 'Amazon.in'], dtype=object)

# %%
df['Visual appealing web-page layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Visual appealing web-page layout'])
plt.show()

# %%
df['Wild variety of product on offer'].unique()
# Out:
# array(['Flipkart.com', 'Flipkart.com, Myntra.com',
#        'Amazon.in, Myntra.com', 'Amazon.in, Flipkart.com', 'Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Paytm.com'],
#       dtype=object)

# %%
df['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
plt.figure(figsize=(26,12))
sns.set_style('darkgrid')
sns.countplot(df['Wild variety of product on offer'])
plt.show()

# %%
df['Complete, relevant description information of products'].unique()
# Out:
# array(['Snapdeal.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Flipkart.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Complete, relevant description information of products'])
plt.show()

# %%
df['Fast loading website speed of website and application'].unique()
# Out:
# array(['Snapdeal.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
df['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
plt.figure(figsize=(30,12))
sns.set_style('darkgrid')
sns.countplot(df['Fast loading website speed of website and application'])
plt.show()

# %%
df['Reliability of the website or application'].unique()
# Out:
# array(['Paytm.com', 'Myntra.com', 'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
plt.figure(figsize=(28,15))
sns.set_style('darkgrid')
sns.countplot(df['Reliability of the website or application'])
plt.show()

# %%
df['Quickness to complete purchase'].unique()
# Out:
# array(['Paytm.com', 'Amazon.com, Flipkart.com, Myntra.com',
#        'Amazon.com, Paytm.com, Myntra.com',
#        'Amazon.com, Flipkart.com, Paytm.com',
#        'Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal',
#        'Amazon.com', 'Flipkart.com, Myntra.com, Snapdeal',
#        'Amazon.com, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Quickness to complete purchase'])
plt.show()

# %%
df['Availability of several payment options'].unique()
# Out:
# array(['Patym.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Patym.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Amazon.in, Flipkart.com',
#        'Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in, Patym.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in',
#        'Flipkart.com'], dtype=object)

# %%
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Availability of several payment options'])
plt.show()

# %%
df['Speedy order delivery '].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Myntra.com', 'Flipkart.com'],
#       dtype=object)

# %%
df['Speedy order delivery '].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                   Amazon.in
# 1                     Amazon.in, Flipkart.com
# 2                                   Amazon.in
# 3       Amazon.in, Flipkart.com, Snapdeal.com
# 4                                   Amazon.in
#                         ...
# 264                                 Amazon.in
# 265                              Flipkart.com
# 266                                 Amazon.in
# 267    Flipkart.com, Myntra.com, Snapdeal.com
# 268                                 Amazon.in
# Name: Speedy order delivery , Length: 269, dtype: object>

# %%
plt.figure(figsize=(22,10))
sns.set_style('darkgrid')
sns.countplot(df['Speedy order delivery '])
plt.show()

# %% [markdown]
# Amazon provides fastest  Order delivery

# %%
df['Privacy of customers’ information'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
df['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Flipkart.com                                                    15
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Privacy of customers’ information'])
plt.show()

# %%
df['Security of customer financial information'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Flipkart.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Snapdeal.com'], dtype=object)

# %%
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Security of customer financial information'])
plt.show()

# %%
df['Perceived Trustworthiness'].unique()
# Out:
# array(['Flipkart.com', 'Myntra.com', 'Amazon.in, Myntra.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Paytm.com'],
#       dtype=object)

# %%
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Perceived Trustworthiness'])
plt.show()

# %%
df['Presence of online assistance through multi-channel'].unique()
# Out:
# array(['Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com', 'Myntra.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal',
#        'Amazon.in, Myntra.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com', 'Amazon.in, Snapdeal',
#        'Flipkart.com'], dtype=object)

# %%
df['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Presence of online assistance through multi-channel'])
plt.show()

# %%
df['Longer time to get logged in (promotion, sales period)'].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com', 'Myntra.com',
#        'Snapdeal.com', 'Flipkart.com, Paytm.com',
#        'Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Flipkart.com'], dtype=object)

# %%
df['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Longer time to get logged in (promotion, sales period)'])
plt.show()

# %%
df['Longer time in displaying graphics and photos (promotion, sales period)'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Myntra.com, Snapdeal.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Myntra.com, Snapdeal.com',
#        'Flipkart.com, Snapdeal.com', 'Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.set_style('darkgrid')
sns.countplot(df['Longer time in displaying graphics and photos (promotion, sales period)'])
plt.show()

# %%
df['Late declaration of price (promotion, sales period)'].unique()
# Out:
# array(['Flipkart.com', 'snapdeal.com', 'Myntra.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in', 'Paytm.com, snapdeal.com',
#        'Amazon.in, Flipkart.com'], dtype=object)

# %%
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(18,10))
sns.set_style('darkgrid')
sns.countplot(df['Late declaration of price (promotion, sales period)'])
plt.show()

# %%
df['Longer page loading time (promotion, sales period)'].unique()
# Out:
# array(['Flipkart.com', 'Snapdeal.com', 'Myntra.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Snapdeal.com', 'Flipkart.com, Snapdeal.com',
#        'Paytm.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Paytm.com, Myntra.com'], dtype=object)

# %%
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(25,12))
sns.set_style('darkgrid')
sns.countplot(df['Longer page loading time (promotion, sales period)'])
plt.show()

# %%
df['Limited mode of payment on most products (promotion, sales period)'].unique()
# Out:
# array(['Amazon.in', 'Snapdeal.com', 'Paytm.com', 'Amazon.in, Paytm.com',
#        'Flipkart.com', 'Amazon.in, Flipkart.com',
#        'Paytm.com, Snapdeal.com', 'Myntra.com, Snapdeal.com'],
#       dtype=object)

# %%
df['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(18,10))
sns.set_style('darkgrid')
sns.countplot(df['Limited mode of payment on most products (promotion, sales period)'])
plt.show()

# %%
df['Longer delivery period'].unique()
# Out:
# array(['Paytm.com', 'Snapdeal.com', 'Flipkart.com', 'Amazon.in',
#        'Paytm.com, Snapdeal.com', 'Myntra.com'], dtype=object)

# %%
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['Longer delivery period'])
plt.show()

# %%
df['Change in website/Application design'].unique()
# Out:
# array(['Flipkart.com', 'Amazon.in', 'Paytm.com',
#        'Amazon.in, Flipkart.com', 'Myntra.com', 'Snapdeal.com',
#        'Flipkart.com, Myntra.com'], dtype=object)

# %%
df['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(df['Change in website/Application design'])
plt.show()

# %%
df['Frequent disruption when moving from one page to another'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Paytm.com', 'Amazon.in, Flipkart.com',
#        'Snapdeal.com', 'Flipkart.com', 'Myntra.com, Snapdeal.com',
#        'Flipkart.com, Snapdeal.com'], dtype=object)

# %%
df['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
plt.figure(figsize=(18,10))
sns.set_style('darkgrid')
sns.countplot(df['Frequent disruption when moving from one page to another'])
plt.show()

# %%
df['Website is as efficient as before'].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Paytm.com', 'Snapdeal.com',
#        'Myntra.com, Snapdeal.com', 'Flipkart.com', 'Amazon.in, Paytm.com'],
#       dtype=object)

# %%
df['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.set_style('darkgrid')
sns.countplot(df['Website is as efficient as before'])
plt.show()

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].unique()
# Out:
# array(['Flipkart.com', 'Amazon.in, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Paytm.com',
#        'Flipkart.com, Paytm.com, Myntra.com, snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com'], dtype=object)

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
plt.figure(figsize=(25,12))
sns.set_style('darkgrid')
sns.countplot(df['Which of the Indian online retailer would you recommend to a friend?'])
plt.show()

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].unique()
# Out:
# array(['Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com, Paytm.com'], dtype=object)

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].unique()
# Out:
# array(['Flipkart.com', 'Amazon.in, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Paytm.com',
#        'Flipkart.com, Paytm.com, Myntra.com, snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com'], dtype=object)

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
plt.figure(figsize=(25,12))
sns.set_style('darkgrid')
sns.countplot(df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '])
plt.show()

# %%
cx = dict({'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0})


for row in df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ']:
  if 'Amazon.in' in row:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in row:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in row:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in row:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in row:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for key, value in cx.items():
  print(f'{value} customers have used the {key} site.')

keys = cx.keys()
values = cx.values()
plt.figure(figsize=(14,8))
plt.bar(keys, values)
plt.show()
# Out:
# 269 customers have used the Amazon.in site.
# 221 customers have used the Flipkart.com site.
# 150 customers have used the Paytm.com site.
# 146 customers have used the Myntra.com site.
# 182 customers have used the Snapdeal.com site.

# %% [markdown]
# #### Most of the customers are using Amazon websites

# %% [markdown]
# #### Flipkart and snapdeal are 2 and 3 position resp.

# %% [markdown]
# #### Paytm and myntra are at bottom

# %%
df['Amazon_customer'] = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].apply(lambda x : 1 if 'Amazon.in' in x else 0)

# %%
df['Flipkart_customer'] = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].apply(lambda x : 1 if 'Amazon.in' in x else 0)

# %%
df['Snapdeal_customer'] = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].apply(lambda x : 1 if 'Amazon.in' in x else 0)

# %%
df['Paytm_customer'] = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].apply(lambda x : 1 if 'Amazon.in' in x else 0)

# %%
df['Myntra_customer'] = df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].apply(lambda x : 1 if 'Amazon.in' in x else 0)

# %% [markdown]
# # Analyzing Dataset on Gender basis:

# %%
online_store = ['Amazon_customer', 'Flipkart_customer', 'Paytm_customer', 'Myntra_customer', 'Snapdeal_customer']


for x in online_store:
  cx = df[df[x]==1]
  plt.figure(figsize=(10,8))
  sns.countplot(cx[x], hue=cx['1Gender of respondent'])
plt.show()

# %% [markdown]
# # Analyzing Dataset on easy to use website or application :

# %%
cx = dict({'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0})



for x in df['Easy to use website or application']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for key, value in cx.items():
  print(f'{value} customers feels that {key} site is easy to use .')

keys = cx.keys()
values = cx.values()
plt.figure(figsize=(14,8))
plt.bar(keys, values)
plt.show()
# Out:
# 249 customers feels that Amazon.in site is easy to use .
# 201 customers feels that Flipkart.com site is easy to use .
# 125 customers feels that Paytm.com site is easy to use .
# 147 customers feels that Myntra.com site is easy to use .
# 130 customers feels that Snapdeal.com site is easy to use .

# %% [markdown]
# from the above graph ,we can see that Most of the customers feel that Amazon is the most easy to use web store followed by Flipkart.

# %% [markdown]
# # Analyzing Data set on Visual appealing web-page layout:

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Visual appealing web-page layout']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site is visually good.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 227 customers feel that the Amazon.in site is visually good.
# 175 customers feel that the Flipkart.com site is visually good.
# 67 customers feel that the Paytm.com site is visually good.
# 115 customers feel that the Myntra.com site is visually good.
# 61 customers feel that the Snapdeal.com site is visually good.

# %% [markdown]
# #### 227 customers feel that the Amazon.in site is visually good.
#
#
# #### 175 customers feel that the Flipkart.com site is visually good.
#
#
# #### 67 customers feel that the Paytm.com site is visually good.
#
#
# #### 115 customers feel that the Myntra.com site is visually good.
#
#
# #### 61 customers feel that the Snapdeal.com site is visually good.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Wild variety of product on offer']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has wide variety of products on offer.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 220 customers feel that the Amazon.in site has wide variety of products on offer.
# 184 customers feel that the Flipkart.com site has wide variety of products on offer.
# 20 customers feel that the Paytm.com site has wide variety of products on offer.
# 64 customers feel that the Myntra.com site has wide variety of products on offer.
# 14 customers feel that the Snapdeal.com site has wide variety of products on offer.

# %% [markdown]
# #### 220 customers feel that the Amazon.in site has wide variety of products on offer.
#
#
# #### 184 customers feel that the Flipkart.com site has wide variety of products on offer.
#
#
# #### 20 customers feel that the Paytm.com site has wide variety of products on offer.
#
#
# #### 64 customers feel that the Myntra.com site has wide variety of products on offer.
#
#
# #### 14 customers feel that the Snapdeal.com site has wide variety of products on offer.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Complete, relevant description information of products']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has complete and relevant description infomration of Products.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 238 customers feel that the Amazon.in site has complete and relevant description infomration of Products.
# 194 customers feel that the Flipkart.com site has complete and relevant description infomration of Products.
# 59 customers feel that the Paytm.com site has complete and relevant description infomration of Products.
# 64 customers feel that the Myntra.com site has complete and relevant description infomration of Products.
# 59 customers feel that the Snapdeal.com site has complete and relevant description infomration of Products.

# %% [markdown]
# #### 238 customers feel that the Amazon.in site has complete and relevant description infomration of Products.
#
#
# #### 194 customers feel that the Flipkart.com site has complete and relevant description infomration of Products.
#
#
# #### 59 customers feel that the Paytm.com site has complete and relevant description infomration of Products.
#
#
# #### 64 customers feel that the Myntra.com site has complete and relevant description infomration of Products.
#
#
# #### 59 customers feel that the Snapdeal.com site has complete and relevant description infomration of Products.

# %% [markdown]
# Amazon and Flipkart sites have the most relevant information on products on the site.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Fast loading website speed of website and application']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has Fast loading website speed of website and application.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 249 customers feel that the Amazon.in site has Fast loading website speed of website and application.
# 162 customers feel that the Flipkart.com site has Fast loading website speed of website and application.
# 99 customers feel that the Paytm.com site has Fast loading website speed of website and application.
# 74 customers feel that the Myntra.com site has Fast loading website speed of website and application.
# 81 customers feel that the Snapdeal.com site has Fast loading website speed of website and application.

# %% [markdown]
# #### 249 customers feel that the Amazon.in site has Fast loading website speed of website and application.
#
#
# #### 162 customers feel that the Flipkart.com site has Fast loading website speed of website and application.
#
#
# #### 99 customers feel that the Paytm.com site has Fast loading website speed of website and application.
#
#
# #### 74 customers feel that the Myntra.com site has Fast loading website speed of website and application.
#
#
# #### 81 customers feel that the Snapdeal.com site has Fast loading website speed of website and application.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Reliability of the website or application']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has Reliability of the website or application.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 227 customers feel that the Amazon.in site has Reliability of the website or application.
# 146 customers feel that the Flipkart.com site has Reliability of the website or application.
# 96 customers feel that the Paytm.com site has Reliability of the website or application.
# 64 customers feel that the Myntra.com site has Reliability of the website or application.
# 45 customers feel that the Snapdeal.com site has Reliability of the website or application.

# %% [markdown]
# #### 227 customers feel that the Amazon.in site has Reliability of the website or application.
# #### 146 customers feel that the Flipkart.com site has Reliability of the website or application.
# #### 96 customers feel that the Paytm.com site has Reliability of the website or application.
# #### 64 customers feel that the Myntra.com site has Reliability of the website or application.
# #### 45 customers feel that the Snapdeal.com site has Reliability of the website or application.

# %%
df['Quickness to complete purchase'].unique()
# Out:
# array(['Paytm.com', 'Amazon.com, Flipkart.com, Myntra.com',
#        'Amazon.com, Paytm.com, Myntra.com',
#        'Amazon.com, Flipkart.com, Paytm.com',
#        'Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal',
#        'Amazon.com', 'Flipkart.com, Myntra.com, Snapdeal',
#        'Amazon.com, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
quik = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Quickness to complete purchase']:
  if 'Amazon.com' in x:
    quik['Amazon.in'] = quik.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    quik['Flipkart.com'] = quik.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    quik['Paytm.com'] = quik.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    quik['Myntra.com'] = quik.get('Myntra.com') + 1
  if 'Snapdeal' in x:
    quik['Snapdeal.com'] = quik.get('Snapdeal.com') + 1
  
for b,v in quik.items():
  print(f'{v} customers feel that the {b} site is quick to complete purchase.')

visual = quik.keys()
value = quik.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 215 customers feel that the Amazon.in site is quick to complete purchase.
# 158 customers feel that the Flipkart.com site is quick to complete purchase.
# 107 customers feel that the Paytm.com site is quick to complete purchase.
# 79 customers feel that the Myntra.com site is quick to complete purchase.
# 29 customers feel that the Snapdeal.com site is quick to complete purchase.

# %% [markdown]
# # Amazon is the quickest to complete purchases.

# %%
df['Availability of several payment options'].unique()
# Out:
# array(['Patym.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Patym.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Amazon.in, Flipkart.com',
#        'Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in, Patym.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in',
#        'Flipkart.com'], dtype=object)

# %%
pmt = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Availability of several payment options']:
  if 'Amazon.in' in x:
    pmt['Amazon.in'] = pmt.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    pmt['Flipkart.com'] = pmt.get('Flipkart.com') + 1
  if 'Patym.com' in x:
    pmt['Paytm.com'] = pmt.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    pmt['Myntra.com'] = pmt.get('Myntra.com') + 1
  if 'Snapdeal' in x:
    pmt['Snapdeal.com'] = pmt.get('Snapdeal.com') + 1
  
for k,v in pmt.items():
  print(f'{v} customers feel that the {k} site has several payment options.')

payment = pmt.keys()
value = pmt.values()
plt.figure(figsize=(14,8))
plt.bar(payment, value)
plt.show()
# Out:
# 215 customers feel that the Amazon.in site has several payment options.
# 203 customers feel that the Flipkart.com site has several payment options.
# 82 customers feel that the Paytm.com site has several payment options.
# 132 customers feel that the Myntra.com site has several payment options.
# 90 customers feel that the Snapdeal.com site has several payment options.

# %% [markdown]
# # Amazon has several payment options.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Perceived Trustworthiness']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has Perceived Trustworthiness.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 227 customers feel that the Amazon.in site has Perceived Trustworthiness.
# 143 customers feel that the Flipkart.com site has Perceived Trustworthiness.
# 24 customers feel that the Paytm.com site has Perceived Trustworthiness.
# 88 customers feel that the Myntra.com site has Perceived Trustworthiness.
# 74 customers feel that the Snapdeal.com site has Perceived Trustworthiness.

# %% [markdown]
# #### Most trustworthy site is Amazon.
#
#
# #### The least trustworthy site per the survey is Paytm.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Longer page loading time (promotion, sales period)']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has Longer page loading time (promotion, sales period).')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 68 customers feel that the Amazon.in site has Longer page loading time (promotion, sales period).
# 61 customers feel that the Flipkart.com site has Longer page loading time (promotion, sales period).
# 94 customers feel that the Paytm.com site has Longer page loading time (promotion, sales period).
# 68 customers feel that the Myntra.com site has Longer page loading time (promotion, sales period).
# 63 customers feel that the Snapdeal.com site has Longer page loading time (promotion, sales period).

# %% [markdown]
# ##### Large number customer thinks Paytm takes longer page loading
#
#
# ##### Few customer think Amazon,flipkart and snapdeal takes longer page loading.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Frequent disruption when moving from one page to another']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers feel that the {b} site has Frequent disruption when moving from one page to another.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 78 customers feel that the Amazon.in site has Frequent disruption when moving from one page to another.
# 62 customers feel that the Flipkart.com site has Frequent disruption when moving from one page to another.
# 39 customers feel that the Paytm.com site has Frequent disruption when moving from one page to another.
# 66 customers feel that the Myntra.com site has Frequent disruption when moving from one page to another.
# 74 customers feel that the Snapdeal.com site has Frequent disruption when moving from one page to another.

# %%
cx = {'Amazon.in':0, 'Flipkart.com':0, 'Paytm.com':0, 'Myntra.com':0, 'Snapdeal.com':0}


for x in df['Which of the Indian online retailer would you recommend to a friend?']:
  if 'Amazon.in' in x:
    cx['Amazon.in'] = cx.get('Amazon.in') + 1
  if 'Flipkart.com' in x:
    cx['Flipkart.com'] = cx.get('Flipkart.com') + 1
  if 'Paytm.com' in x:
    cx['Paytm.com'] = cx.get('Paytm.com') + 1
  if 'Myntra.com' in x:
    cx['Myntra.com'] = cx.get('Myntra.com') + 1
  if 'Snapdeal.com' in x:
    cx['Snapdeal.com'] = cx.get('Snapdeal.com') + 1
  
for b,vis in cx.items():
  print(f'{vis} customers has recommended the {b} site.')


visual = cx.keys()
value = cx.values()
plt.figure(figsize=(14,8))
plt.bar(visual, value)
plt.show()
# Out:
# 219 customers has recommended the Amazon.in site.
# 127 customers has recommended the Flipkart.com site.
# 44 customers has recommended the Paytm.com site.
# 76 customers has recommended the Myntra.com site.
# 0 customers has recommended the Snapdeal.com site.

# %% [markdown]
# # Amazon is the most recommended store followed by Flipkart.
